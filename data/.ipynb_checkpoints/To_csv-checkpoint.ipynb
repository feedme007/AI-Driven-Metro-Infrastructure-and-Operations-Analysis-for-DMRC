# %% [markdown]
# ### geojson to csv

# %%
import geopandas as gpd
import pandas as pd

# Load GeoJSON file into a GeoDataFrame
gdf = gpd.read_file('../Line 2/TTC - 2 LINE 2 (BLOOR - DANFORTH) - Stops.geojson')

# Convert GeoDataFrame to DataFrame
df = pd.DataFrame(gdf.drop(columns='geometry'))  # Drop the geometry column if you don't need it

# If you want to keep latitude and longitude
df['latitude'] = gdf.geometry.y
df['longitude'] = gdf.geometry.x

# Save the DataFrame to CSV
df.to_csv('../Line 2/Stops.csv', index=False)

print("GeoJSON has been converted to CSV and saved.")
# Out:
# GeoJSON has been converted to CSV and saved.

# %% [markdown]
# ### txt to csv

# %%
import csv

# Specify the input and output file paths
input_file_path = '../TTC/stop_times.txt'
output_file_path = '../TTC/stop_times.csv'

# Open the input text file and output CSV file
with open(input_file_path, 'r') as txt_file, open(output_file_path, 'w', newline='') as csv_file:
    # Create a CSV writer object
    csv_writer = csv.writer(csv_file)

    # Iterate over each line in the text file
    for line in txt_file:
        # Split the line by comma to get the values
        values = line.strip().split(',')
        # Write the values as a row in the CSV file
        csv_writer.writerow(values)

print(f"Conversion complete! The CSV file is saved as {output_file_path}.")
# Out:
# Conversion complete! The CSV file is saved as ../TTC/stop_times.csv.

# %%
import pandas as pd
import json
import requests

# %%
--generate-config
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 --generate-config
#
# NameError: name 'generate' is not defined

# %%
response = requests.get('http://gtfs.ltconline.ca/TripUpdate/TripUpdates.json')
data = response.json()
print(data)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
import pandas as pd

# Extract the 'entity' list from the JSON data
entities = data['entity']

# Create a DataFrame from the 'entity' list
df = pd.json_normalize(entities)
# Out:
#        id  is_deleted trip_update vehicle shape  trip route  stop  \
# 0   19380       False        None    None  None  None  None  None
# 1   23168       False        None    None  None  None  None  None
# 2   27754       False        None    None  None  None  None  None
# 3   27755       False        None    None  None  None  None  None
# 4   27771       False        None    None  None  None  None  None
# 5   30062       False        None    None  None  None  None  None
# 6   31734       False        None    None  None  None  None  None
# 7   31735       False        None    None  None  None  None  None
# 8   31736       False        None    None  None  None  None  None
# 9   31747       False        None    None  None  None  None  None
# 10  31748       False        None    None  None  None  None  None
# 11  31749       False        None    None  None  None  None  None
# 12  31750       False        None    None  None  None  None  None
# ...

# %%
df.to_csv("Alerts.csv",index=False)

# %%
df_alerts = pd.read_csv("Alerts.csv")
df_alerts
# Out:
#        id  is_deleted  trip_update  vehicle  shape  trip  route  stop  \
# 0   19380       False          NaN      NaN    NaN   NaN    NaN   NaN
# 1   23168       False          NaN      NaN    NaN   NaN    NaN   NaN
# 2   27754       False          NaN      NaN    NaN   NaN    NaN   NaN
# 3   27755       False          NaN      NaN    NaN   NaN    NaN   NaN
# 4   27771       False          NaN      NaN    NaN   NaN    NaN   NaN
# 5   30062       False          NaN      NaN    NaN   NaN    NaN   NaN
# 6   31734       False          NaN      NaN    NaN   NaN    NaN   NaN
# 7   31735       False          NaN      NaN    NaN   NaN    NaN   NaN
# 8   31736       False          NaN      NaN    NaN   NaN    NaN   NaN
# 9   31747       False          NaN      NaN    NaN   NaN    NaN   NaN
# 10  31748       False          NaN      NaN    NaN   NaN    NaN   NaN
# 11  31749       False          NaN      NaN    NaN   NaN    NaN   NaN
# ...

# %%
df_trip_faraz = pd.read_csv('Alerts_faraz.csv')
df_trip_faraz
# Out:
#         id  is_deleted  trip_update  vehicle  alert/active_period/0/start  \
# 0    19380       False          NaN      NaN                   1677664800
# 1    23168       False          NaN      NaN                   1692352800
# 2    23802       False          NaN      NaN                   1694176500
# 3    26327       False          NaN      NaN                   1699351200
# 4    26328       False          NaN      NaN                   1699351200
# ..     ...         ...          ...      ...                          ...
# 109  32508       False          NaN      NaN                   1720208940
# 110  32509       False          NaN      NaN                   1720209060
# 111  32510       False          NaN      NaN                   1720209120
# 112  32522       False          NaN      NaN                   1720309560
# 113  32523       False          NaN      NaN                   1720308780
#
#      alert/active_period/0/end  alert/informed_entity/0/agency_id  \
# ...

# %%
df.isna().sum()
# Out:
# id                                                         0
# is_deleted                                                 0
# trip_update/trip/trip_id                                   0
# trip_update/trip/start_time                                0
# trip_update/trip/start_date                                0
#                                                         ...
# trip_update/stop_time_update/44/arrival/uncertainty      373
# trip_update/stop_time_update/44/arrival/schedule_time    373
# trip_update/stop_time_update/77/departure                377
# trip_update/stop_time_update/89/departure                377
# trip_update/stop_time_update/90/departure                377
# Length: 1923, dtype: int64
