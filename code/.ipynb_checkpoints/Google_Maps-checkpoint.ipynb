# %%
pip install googlemaps
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
Castle Frank
Broadview
Chester
Pape
Donlands
Greenwood
Coxwell
Woodbine
Main Street
Victoria Park
Warden
Kennedy

# %%
import googlemaps
from datetime import datetime

# Replace with your Google Maps API key
api_key = "AIzaSyCbHiUycFCpZWEo_22-ynLifdmt7EA72RQ"

# Initialize the client
gmaps = googlemaps.Client(key=api_key)

# Define the parameters
origin = "Castle Frank Station, Toronto, ON"
destination = "Kennedy Station, Toronto, ON"
mode = "transit"

# Fetch the transit directions
now = datetime.now()
directions_result = gmaps.directions(origin,
                                     destination,
                                     mode=mode,
                                     departure_time=now)

# Extract real-time details
for step in directions_result[0]['legs'][0]['steps']:
    if step['travel_mode'] == 'TRANSIT':
        transit_details = step['transit_details']
        line_name = transit_details['line']['short_name']
        arrival_time = transit_details['arrival_time']['text']
        departure_time = transit_details['departure_time']['text']
        print(f"Line: {line_name}")
        print(f"Departure: {departure_time}")
        print(f"Arrival: {arrival_time}")
# Out:
# Line: 2
# Departure: 12:25 AM
# Arrival: 12:45 AM

# %%
def fetch_realtime_transit(origin, destination):
    directions_result = gmaps.directions(origin,
                                     destination,
                                     mode = "transit",
                                     departure_time=now)
    available_transit=[]
    
    # Extract real-time details
    for step in directions_result[0]['legs'][0]['steps']:
        if step['travel_mode'] == 'TRANSIT':
            transit_details = step['transit_details']
            line_name = transit_details['line']['short_name']
            arrival_time = transit_details['arrival_time']['text']
            departure_time = transit_details['departure_time']['text']
            available_transit.append({
                                       'line_name':line_name,
                                       'arrival_time': arrival_time,
                                       'departure_time': departure_time
                                     })

    return available_transit

# %%
origin = "Castle Frank Station, Toronto, ON"
destination = "Kenndy Station, Toronto, ON"
print(fetch_realtime_transit(origin, destination))
# Out:
# [{'line_name': '2', 'arrival_time': '11:51\u202fPM', 'departure_time': '11:31\u202fPM'}]

# %%
import requests

def get_weather(api_key, latitude, longitude):
    url = f"http://api.openweathermap.org/data/2.5/weather?lat={latitude}&lon={longitude}&appid={api_key}&units=metric"
    response = requests.get(url)
    data = response.json()
    weather = data['weather'][0]['main']  # General weather condition
    temperature = data['main']['temp']  # Temperature in Celsius
    return weather, temperature

# %%
from datetime import datetime, timedelta
import schedule
import time
import pandas as pd
import googlemaps

# Initialize Google Maps API
api_key = "AIzaSyCbHiUycFCpZWEo_22-ynLifdmt7EA72RQ"
gmaps = googlemaps.Client(key=api_key)

stations = [
    "Castle Frank Station, Toronto, ON",
    "Broadview Station, Toronto, ON",
    "Chester Station, Toronto, ON",
    "Pape Station, Toronto, ON",
    "Donlands Station, Toronto, ON",
    "Greenwood Station, Toronto, ON",
    "Coxwell Station, Toronto, ON",
    "Woodbine Station, Toronto, ON",
    "Main Street Station, Toronto, ON",
    "Victoria Park Station, Toronto, ON",
    "Warden Station, Toronto, ON",
    "Kennedy Station, Toronto, ON"
]

def fetch_transit_details():
    now = datetime.now()
    transit_data = []
    for i in range(len(stations)-1):
        origin = stations[i]
        destination = stations[i+1]
        directions_result = gmaps.directions(origin, destination, mode="transit", departure_time=now)
        for step in directions_result[0]['legs'][0]['steps']:
            if step['travel_mode'] == 'TRANSIT':
                transit_details = step['transit_details']
                arrival_time_dt = datetime.fromtimestamp(transit_details['arrival_time']['value'])  # Convert to datetime
                departure_time_dt = datetime.fromtimestamp(transit_details['departure_time']['value'])  # Convert to datetime
                if arrival_time_dt - now <= timedelta(minutes=1):
                    transit_data.append({
                        'stop_name': origin.split(",")[0],
                        'line_name': transit_details['line']['short_name'],
                        'arrival_time': transit_details['arrival_time']['text'],
                        'departure_time': transit_details['departure_time']['text']
                    })
    return transit_data

def record_transit_times():
    df = pd.DataFrame(fetch_transit_details())
    df.to_csv('transit_times.csv', mode='a', header=False, index=False)

schedule.every().minute.do(record_transit_times)

start_time = time.time()
while (time.time() - start_time) < 120:  # 300 seconds = 5 minutes
    schedule.run_pending()
    time.sleep(1)

# %%
from datetime import datetime, timedelta
import schedule
import time
import pandas as pd
import googlemaps

# Initialize Google Maps API
api_key = "AIzaSyCbHiUycFCpZWEo_22-ynLifdmt7EA72RQ"
gmaps = googlemaps.Client(key=api_key)

stations = [
    "Castle Frank Station, Toronto, ON",
    "Broadview Station, Toronto, ON",
    "Chester Station, Toronto, ON",
    "Pape Station, Toronto, ON",
    "Donlands Station, Toronto, ON",
    "Greenwood Station, Toronto, ON",
    "Coxwell Station, Toronto, ON",
    "Woodbine Station, Toronto, ON",
    "Main Street Station, Toronto, ON",
    "Victoria Park Station, Toronto, ON",
    "Warden Station, Toronto, ON",
    "Kennedy Station, Toronto, ON"
]

def fetch_transit_details():
    now = datetime.now()
    transit_data = []
    for i in range(len(stations)-1):
        origin = stations[i]
        destination = stations[i+1]
        directions_result = gmaps.directions(origin, destination, mode="transit", departure_time=now)
        for step in directions_result[0]['legs'][0]['steps']:
            if step['travel_mode'] == 'TRANSIT':
                transit_details = step['transit_details']
                arrival_time_dt = datetime.fromtimestamp(transit_details['arrival_time']['value'])  # Convert to datetime
                departure_time_dt = datetime.fromtimestamp(transit_details['departure_time']['value'])  # Convert to datetime
                print(f"Checking {origin.split(',')[0]} to {destination.split(',')[0]} at {now.strftime('%Y-%m-%d %H:%M:%S')}")
                if (arrival_time_dt - now).total_seconds() <= 120:
                    transit_data.append({
                        'stop_name': origin.split(",")[0],
                        'line_name': transit_details['line']['short_name'],
                        'arrival_time': transit_details['arrival_time']['text'],
                        'departure_time': transit_details['departure_time']['text']
                    })
    if transit_data:
        print(f"Data found and saved: {transit_data}")
    else:
        print("No data meeting the criteria found.")
    return transit_data

def record_transit_times():
    df = pd.DataFrame(fetch_transit_details())
    if not df.empty:
        df.to_csv('transit_times.csv', mode='a', header=False, index=False)
        print("Data has been written to CSV.")
    else:
        print("No data to write.")

# Scheduling the function to run every minute
schedule.every().minute.do(record_transit_times)

# Running the scheduler
start_time = time.time()
while (time.time() - start_time) < 120:  # 120 seconds = 2 minutes
    schedule.run_pending()
    time.sleep(1)
# Out:
# Checking Castle Frank Station to Broadview Station at 2024-08-10 23:56:04
# Checking Broadview Station to Chester Station at 2024-08-10 23:56:04
# Checking Chester Station to Pape Station at 2024-08-10 23:56:04
# Checking Pape Station to Donlands Station at 2024-08-10 23:56:04
# Checking Donlands Station to Greenwood Station at 2024-08-10 23:56:04
# Checking Greenwood Station to Coxwell Station at 2024-08-10 23:56:04
# Checking Coxwell Station to Woodbine Station at 2024-08-10 23:56:04
# Checking Woodbine Station to Main Street Station at 2024-08-10 23:56:04
# Checking Main Street Station to Victoria Park Station at 2024-08-10 23:56:04
# Checking Victoria Park Station to Warden Station at 2024-08-10 23:56:04
# Checking Warden Station to Kennedy Station at 2024-08-10 23:56:04
# No data meeting the criteria found.
# No data to write.
# Checking Castle Frank Station to Broadview Station at 2024-08-10 23:56:05
# Checking Broadview Station to Chester Station at 2024-08-10 23:56:05
# ...

# %%
from datetime import datetime, timedelta
import schedule
import time
import pandas as pd
import googlemaps

# Initialize Google Maps API
api_key = "AIzaSyCbHiUycFCpZWEo_22-ynLifdmt7EA72RQ"
gmaps = googlemaps.Client(key=api_key)

stations = [
    "Castle Frank Station, Toronto, ON",
    "Broadview Station, Toronto, ON",
    "Chester Station, Toronto, ON",
    "Pape Station, Toronto, ON",
    "Donlands Station, Toronto, ON",
    "Greenwood Station, Toronto, ON",
    "Coxwell Station, Toronto, ON",
    "Woodbine Station, Toronto, ON",
    "Main Street Station, Toronto, ON",
    "Victoria Park Station, Toronto, ON",
    "Warden Station, Toronto, ON",
    "Kennedy Station, Toronto, ON"
]

def fetch_transit_details():
    now = datetime.now()
    transit_data = []
    for i in range(len(stations)-1):
        origin = stations[i]
        destination = stations[i+1]
        directions_result = gmaps.directions(origin, destination, mode="transit", departure_time=now)
        for step in directions_result[0]['legs'][0]['steps']:
            if step['travel_mode'] == 'TRANSIT':
                transit_details = step['transit_details']
                arrival_time_dt = datetime.fromtimestamp(transit_details['arrival_time']['value'])  # Convert to datetime
                departure_time_dt = datetime.fromtimestamp(transit_details['departure_time']['value'])  # Convert to datetime
                print(f"Checking {origin.split(',')[0]} to {destination.split(',')[0]} at {now.strftime('%Y-%m-%d %H:%M:%S')}")
                print(f"Arrival Time: {arrival_time_dt.strftime('%Y-%m-%d %H:%M:%S')}, 'Departure Time: {departure_time_dt.strftime('%Y-%m-%d %H:%M:%S')}, Now: {now.strftime('%Y-%m-%d %H:%M:%S')}")
                if (departure_time_dt - now).total_seconds() <= 120:
                    transit_data.append({
                        'stop_name': origin.split(",")[0],
                        # 'line_name': transit_details['line']['short_name'],
                        'arrival_time': transit_details['departure_time']['text'],
                        # 'departure_time': transit_details['departure_time']['text']
                    })
    if transit_data:
        print(f"Data found and saved: {transit_data}")
    else:
        print("No data meeting the criteria found.")
    return transit_data

import os

def record_transit_times():
    # Define the file path
    file_path = 'transit_times.csv'
    
    # Fetch transit details
    df = pd.DataFrame(fetch_transit_details())
    
    # Check if the file exists
    if not df.empty:
        if not os.path.isfile(file_path):  # If file does not exist, write with headers
            df.to_csv(file_path, mode='w', header=True, index=False)
            print("Data has been written to CSV with headers.")
        else:  # If file exists, append without headers
            df.to_csv(file_path, mode='a', header=False, index=False)
            print("Data has been appended to CSV without headers.")
    else:
        print("No data to write.")


# Scheduling the function to run every minute
schedule.every().minute.do(record_transit_times)

# Running the scheduler
start_time = time.time()
while (time.time() - start_time) < 300:  # 120 seconds = 2 minutes
    schedule.run_pending()
    time.sleep(1)
# Out:
# Checking Castle Frank Station to Broadview Station at 2024-08-11 21:50:27
# Arrival Time: 2024-08-11 21:54:34, 'Departure Time: 2024-08-11 21:52:47, Now: 2024-08-11 21:50:27
# Checking Broadview Station to Chester Station at 2024-08-11 21:50:27
# Arrival Time: 2024-08-11 21:55:37, 'Departure Time: 2024-08-11 21:54:34, Now: 2024-08-11 21:50:27
# Checking Chester Station to Pape Station at 2024-08-11 21:50:27
# Arrival Time: 2024-08-11 21:57:10, 'Departure Time: 2024-08-11 21:55:37, Now: 2024-08-11 21:50:27
# Checking Pape Station to Donlands Station at 2024-08-11 21:50:27
# Arrival Time: 2024-08-11 21:52:55, 'Departure Time: 2024-08-11 21:51:40, Now: 2024-08-11 21:50:27
# Checking Donlands Station to Greenwood Station at 2024-08-11 21:50:27
# Arrival Time: 2024-08-11 21:53:55, 'Departure Time: 2024-08-11 21:52:55, Now: 2024-08-11 21:50:27
# Checking Greenwood Station to Coxwell Station at 2024-08-11 21:50:27
# ...

# %%
import schedule
import time
import pandas as pd
import googlemaps
import requests
import os
from datetime import datetime

# Initialize Google Maps API and Weather API Key globally
google_api_key = "AIzaSyCbHiUycFCpZWEo_22-ynLifdmt7EA72RQ"
weather_api_key = "2fe681d1e2bde113e43c4d0ddbda4d8f"
gmaps = googlemaps.Client(key=google_api_key)

stations = [
    "Castle Frank Station, Toronto, ON",
    "Broadview Station, Toronto, ON",
    "Chester Station, Toronto, ON",
    "Pape Station, Toronto, ON",
    "Donlands Station, Toronto, ON",
    "Greenwood Station, Toronto, ON",
    "Coxwell Station, Toronto, ON",
    "Woodbine Station, Toronto, ON",
    "Main Street Station, Toronto, ON",
    "Victoria Park Station, Toronto, ON",
    "Warden Station, Toronto, ON",
    "Kennedy Station, Toronto, ON"
]

def get_weather(latitude, longitude):
    url = f"http://api.openweathermap.org/data/2.5/weather?lat={latitude}&lon={longitude}&appid={weather_api_key}&units=metric"
    response = requests.get(url)
    data = response.json()
    weather = data['weather'][0]['main']  # General weather condition
    temperature = data['main']['temp']  # Temperature in Celsius
    return weather, temperature

def fetch_transit_details():
    now = datetime.now()
    transit_data = []
    # Downtown, Toronto
    latitude = 43.6548
    longitude = -79.3883
    weather, temperature = get_weather(latitude, longitude)
    
    for i in range(len(stations)-1):
        origin = stations[i]
        destination = stations[i+1]
        directions_result = gmaps.directions(origin, destination, mode="transit", departure_time=now)
        for step in directions_result[0]['legs'][0]['steps']:
            if step['travel_mode'] == 'TRANSIT':
                transit_details = step['transit_details']
                arrival_time_dt = datetime.fromtimestamp(transit_details['arrival_time']['value'])
                departure_time_dt = datetime.fromtimestamp(transit_details['departure_time']['value'])
                print(f"{origin.split(',')[0]}, Arrival Time: {departure_time_dt.strftime('%Y-%m-%d %H:%M:%S')}, Now: {now.strftime('%Y-%m-%d %H:%M:%S')}")
                if (departure_time_dt - now).total_seconds() <= 160:
                    transit_data.append({
                        'stop_name': origin.split(",")[0],
                        'arrival_time': departure_time_dt.strftime('%H:%M:%S'),
                        'weather': weather,
                        'temperature': temperature
                    })
    return transit_data


def record_transit_times():
    df = pd.DataFrame(fetch_transit_details())
    display(df)
    file_path = 'transit_times.csv'
    # Drop duplicates based on stop_name and arrival_time
    df = df.drop_duplicates(subset=['stop_name', 'arrival_time'], keep='first')
    if not df.empty:
        if not os.path.isfile(file_path):
            df.to_csv(file_path, mode='w', header=True, index=False)
            print("Data has been written to CSV with headers.")
        else:
            df.to_csv(file_path, mode='a', header=False, index=False)
            print("Data has been appended to CSV without headers.")

# Set up the schedule to call record_transit_times directly
schedule.every().minute.do(record_transit_times)

# Running the scheduler
start_time = time.time()
while (time.time() - start_time) < 600:  # 300 seconds = 5 minutes
    schedule.run_pending()
    time.sleep(1)
# Out:
# Castle Frank Station, Arrival Time: 2024-08-12 01:43:58, Now: 2024-08-12 01:42:47
# Broadview Station, Arrival Time: 2024-08-12 01:45:45, Now: 2024-08-12 01:42:47
# Chester Station, Arrival Time: 2024-08-12 01:46:44, Now: 2024-08-12 01:42:47
# Pape Station, Arrival Time: 2024-08-12 01:48:11, Now: 2024-08-12 01:42:47
# Donlands Station, Arrival Time: 2024-08-12 01:49:20, Now: 2024-08-12 01:42:47
# Greenwood Station, Arrival Time: 2024-08-12 01:50:20, Now: 2024-08-12 01:42:47
# Coxwell Station, Arrival Time: 2024-08-12 01:45:20, Now: 2024-08-12 01:42:47
# Woodbine Station, Arrival Time: 2024-08-12 01:47:20, Now: 2024-08-12 01:42:47
# Main Street Station, Arrival Time: 2024-08-12 01:48:46, Now: 2024-08-12 01:42:47
# Victoria Park Station, Arrival Time: 2024-08-12 01:44:35, Now: 2024-08-12 01:42:47
# Warden Station, Arrival Time: 2024-08-12 01:47:50, Now: 2024-08-12 01:42:47
#                stop_name arrival_time weather  temperature
# ...

# %%
df = pd.read_csv('transit_times.csv')
# Drop duplicates based on stop_name and arrival_time
df = df.drop_duplicates(subset=['stop_name', 'arrival_time'], keep='first')
df.to_csv('transit_times.csv', index = False)

# %%
api_key = "AIzaSyCbHiUycFCpZWEo_22-ynLifdmt7EA72RQ"

# %%
open weather
2fe681d1e2bde113e43c4d0ddbda4d8f
